# %%
import tensorflow as tf 
from tensorflow import keras
import numpy as np 
import matplotlib.pyplot as plt

data = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = data.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images = train_images/255.0
test_images = test_images/255.0

# %%
model = keras.Sequential([
	keras.layers.Flatten(input_shape=(28,28)),
	keras.layers.Dense(128, activation="relu"),
	keras.layers.Dense(10, activation="softmax")
	])

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.4979 - accuracy: 0.8243
# Epoch 2/5
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.3808 - accuracy: 0.8624
# Epoch 3/5
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.3407 - accuracy: 0.8755
# Epoch 4/5
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.3154 - accuracy: 0.8841
# Epoch 5/5
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.2966 - accuracy: 0.8894

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)

print('\nTest accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 0s 42us/sample - loss: 0.3551 - accuracy: 0.8753
#
# Test accuracy: 0.8753

# %%
predictions = model.predict(test_images)

# %%
plt.figure(figsize=(5,5))
for i in range(5):
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[test_labels[i]])
    plt.title(class_names[np.argmax(predictions[i])])
    plt.show()
